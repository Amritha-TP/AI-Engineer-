# %% [markdown]
# ## Task 1
# Give 2 examples of all String functions which should be meaningful.

# %%
user_input = input("Enter your input:")
print("                                              ")
print("1. Converted the first character to upper case:",user_input.capitalize()) 
print("                                              ")
print("2. Converts string into lower case:",user_input.casefold())
print("                                              ")
print("3. Returns a centered string with the given width and padding character:{}".format(user_input.center(10,"=")))
print("                                              ")
print("4. Returns the number of times a specified value occurs in a string:",user_input.casefold().count("e"))
print("                                              ")
print("5. Returns true if the string ends with the specified value:",user_input.endswith("."))
print("                                              ")
print("6. Sets the tab size of the string:","New\tJersey".expandtabs(10))
print("                                              ")
print("7. Searches the string for a specified value and returns the position of where it was found:",user_input.find("a"))
print("                                              ")
print("8. Formats specified values in a string: the given input is {}".format(user_input))
print("                                              ")

items_buy= {"Name":"Amritha", "Degree":"B.Tech"}
print("9. Formats specified values from a dictionary in a string:","{Name} is a {Degree} candidate".format_map(items_buy))
# Out:
# Enter your input: amri
#
# 1. Converted the first character to upper case: Amri
#
# 2. Converts string into lower case: amri
#
# 3. Returns a centered string with the given width and padding character:===amri===
#
# 4. Returns the number of times a specified value occurs in a string: 0
#
# 5. Returns true if the string ends with the specified value: False
#
# 6. Sets the tab size of the string: New       Jersey
#
# 7. Searches the string for a specified value and returns the position of where it was found: 0
#
# 8. Formats specified values in a string: the given input is amri
#
# 9. Formats specified values from a dictionary in a string: Amritha is a B.Tech candidate

# %% [markdown]
# #### 10. index() Searches the string for a specified value and returns the position of where it was found

# %%
fruits = "mango"
fruits.index("o")
# Out:
# 4

# %%
color = "yellow"
color.index("l")
# Out:
# 2

# %% [markdown]
# ### 11. isalnum()	Returns True if all characters in the string are alphanumeric
#
# The isalnum() method returns True if all the characters are alphanumeric, meaning alphabet letter (a-z) and numbers (0-9).
#
# Example of characters that are not alphanumeric: (space)!#%&? etc.

# %%
user_id = "amri123"
user_id.isalnum()
# Out:
# True

# %%
emp_id = "amri 123"
emp_id.isalnum()
# Out:
# False

# %% [markdown]
# ### 12. isalpha()	Returns True if all characters in the string are in the alphabet

# %%
name = "Ram"
name.isalpha()
# Out:
# True

# %%
grade = "1"
grade.isalpha()
# Out:
# False

# %% [markdown]
# ### 13. The isascii() method returns True if all the characters are ascii characters.

# %%
game = "Hockey"
game.isascii()
# Out:
# True

# %%
game_1 ="foot ball"
game_1.isascii()
# Out:
# True

# %%
game_2 ="football2$"
game_2.isascii()
# Out:
# True

# %% [markdown]
# ### 14. isdecimal()	Returns True if all characters in the string are decimals

# %%
cgpa="4.5"
cgpa.isdecimal()
# Out:
# False

# %%
cgpa="4"
cgpa.isdecimal()
# Out:
# True

# %% [markdown]
# ### 15. isdigit()	Returns True if all characters in the string are digits

# %%
cgpa="4.5"
cgpa.isdigit()
# Out:
# False

# %%
cgpa="4"
cgpa.isdecimal()
# Out:
# True

# %% [markdown]
# ### 16. isidentifier()	Returns True if the string is an identifier
#
# The isidentifier() method returns True if the string is a valid identifier, otherwise False.
#
# A string is considered a valid identifier if it only contains alphanumeric letters (a-z) and (0-9), or underscores (_). A valid identifier cannot start with a number, or contain any spaces.

# %%
message ="hi"
message.isidentifier()
# Out:
# True

# %%
message_2 ="3hi"
message_2.isidentifier()
# Out:
# False

# %% [markdown]
# ### 17. islower()	Returns True if all characters in the string are lower case

# %%
country = "japan"
country.islower()
# Out:
# True

# %%
country_1 = "JapaN"
country_1.islower()
# Out:
# False

# %% [markdown]
# ### 18. The isprintable() method returns True if all the characters are printable, otherwise False.
#
# Example of none printable character can be carriage return and line feed.

# %%
message_3 ="Hello world"
message_3.isprintable()
# Out:
# True

# %%
message_4="Hello\t world"
message_4.isprintable()
# Out:
# False

# %% [markdown]
# ### 19. The isspace() method returns True if all the characters in a string are whitespaces, otherwise False.

# %%
txt ="hi"
txt.isspace()
# Out:
# False

# %%
txt1="           "
txt1.isspace()
# Out:
# True

# %% [markdown]
# ### 20. istitle()	Returns True if the string follows the rules of a title

# %%
country ="India"
country.istitle()
# Out:
# True

# %%
country ="india"
country.istitle()
# Out:
# False

# %% [markdown]
# ### 21. isupper()	Returns True if all characters in the string are upper case

# %%
phone ="oPpo"
phone.isupper()
# Out:
# False

# %%
phone_2 ="NOKIA"
phone_2.isupper()
# Out:
# True

# %% [markdown]
# ### 22. join()	Converts the elements of an iterable into a string

# %%
toppers = ("Ram","Harish","vishal")
result = ",".join(toppers)
result
# Out:
# 'Ram,Harish,vishal'

# %%
below_average =["vinu","suresh","aahan"]
result_1="-".join(below_average)
result_1
# Out:
# 'vinu-suresh-aahan'

# %% [markdown]
# ### 23. ljust()	Returns a left justified version of the string

# %%
"The".ljust(5,"_")
# Out:
# 'The__'

# %%
"The Boat".ljust(5,"_")
# Out:
# 'The Boat'

# %% [markdown]
# ### 24. lower()	Converts a string into lower case

# %%
"ToYota".lower()
# Out:
# 'toyota'

# %%
"CARS".lower()
# Out:
# 'cars'

# %% [markdown]
# ### 25. encode()	Returns an encoded version of the string

# %%
"a".encode()
# Out:
# b'a'

# %%
"apple".encode(encoding='utf-8')
# Out:
# b'apple'

# %% [markdown]
# ### 26. lstrip()	Returns a left trim version of the string

# %%
" data".lstrip()
# Out:
# 'data'

# %%
"***data".lstrip("*")
# Out:
# 'data'

# %% [markdown]
# ### 27.isnumeric()	Returns True if all characters in the string are numeric

# %%
"2".isnumeric()
# Out:
# True

# %%
"a".isnumeric()
# Out:
# False

# %%
"2a".isnumeric()
# Out:
# False

# %% [markdown]
# ### 28. maketrans()	Returns a translation table to be used in translations

# %%
txt = "Strong"
assign_value=str.maketrans("o","i")
print(assign_value)
print(txt.translate(assign_value))
# Out:
# {111: 105}
# String

# %%
secert_message = "tableti"
code_alpha=str.maketrans("abcdefghi", "123456789") #it matches character by character
print(code_alpha)
print(secert_message.translate(code_alpha))
# Out:
# {97: 49, 98: 50, 99: 51, 100: 52, 101: 53, 102: 54, 103: 55, 104: 56, 105: 57}
# t12l5t9

# %% [markdown]
# ### 29. partition()	Returns a tuple where the string is parted into three parts

# %%
"first_number=second_number=third_number".partition("=")
# Out:
# ('first_number', '=', 'second_number=third_number')

# %%
"first_number=second_number".partition("=")
# Out:
# ('first_number', '=', 'second_number')

# %%
"ultra+".partition("+")
# Out:
# ('ultra', '+', '')

# %% [markdown]
# ### 30. replace()	Returns a string where a specified value is replaced with a specified value

# %%
"hello world".replace("hello","Hi")
# Out:
# 'Hi world'

# %%
"Data".replace("at","e")
# Out:
# 'Dea'

# %% [markdown]
# ### 31. rfind()	Searches the string for a specified value and returns the last position of where it was found

# %%
"yellow".rfind("l")
# Out:
# 3

# %%
"yellow".rfind("u")
# Out:
# -1

# %% [markdown]
# ### 32. rindex()	Searches the string for a specified value and returns the last position of where it was found

# %%
"Hi welcome all".rindex("l")
# Out:
# 13

# %%
"hope you are good".rindex("o",3,9)
# Out:
# 6

# %% [markdown]
# ### 33. rjust()	Returns a right justified version of the string

# %%
"letter".rjust(10,"+")
# Out:
# '++++letter'

# %%
"letter".rjust(10)
# Out:
# '    letter'

# %% [markdown]
# ### 34. rpartition()	Returns a tuple where the string is parted into three parts

# %%
" I learn everday, I learn python".rpartition("learn")
# Out:
# (' I learn everday, I ', 'learn', ' python')

# %%
"solid -> liquid -> gas".rpartition("->")
# Out:
# ('solid -> liquid ', '->', ' gas')

# %% [markdown]
# ### 35. rsplit()	Splits the string at the specified separator, and returns a list

# %%
"blue,black,brown".rsplit(",")
# Out:
# ['blue', 'black', 'brown']

# %%
"blue,black,brown".rsplit(",",1) # setting the maxsplit parameter to 1, will return a list with 2 elements!
# Out:
# ['blue,black', 'brown']

# %%
"blue,black,brown,pink".rsplit(",",2)
# Out:
# ['blue,black', 'brown', 'pink']

# %% [markdown]
# ### 36. split()	Splits the string at the specified separator, and returns a list

# %%
"pandas#numpy#matplotlib".split()
# Out:
# ['pandas#numpy#matplotlib']

# %%
"pandas#numpy#matplotlib".split("#")
# Out:
# ['pandas', 'numpy', 'matplotlib']

# %%
"pandas#numpy#matplotlib".split("#",1)
# Out:
# ['pandas', 'numpy#matplotlib']

# %%
"pandas#numpy#matplotlib".split("8")
# Out:
# ['pandas#numpy#matplotlib']

# %% [markdown]
# ### 37. splitlines()	Splits the string at line breaks and returns a list

# %%
"Hello Learner!\nComplete the module1 task".splitlines()
# Out:
# ['Hello Learner!', 'Complete the module1 task']

# %%
"Hello Learner!\nComplete the module1 task".splitlines(False)
# Out:
# ['Hello Learner!', 'Complete the module1 task']

# %%
"Hello Learner!\nComplete the module1 task".splitlines(True)
# Out:
# ['Hello Learner!\n', 'Complete the module1 task']

# %% [markdown]
# ### 38. startswith()	Returns true if the string starts with the specified value

# %%
"Data Science".startswith("Data")
# Out:
# True

# %%
"AI Engineer".startswith("Data")
# Out:
# False

# %% [markdown]
# ### 39.strip()	Returns a trimmed version of the string

# %%
"          course    ".strip()
# Out:
# 'course'

# %%
"..yyytttocourse  ".strip(".yto ") #Remove the leading and trailing characters
# Out:
# 'course'

# %% [markdown]
# ### 40. swapcase()	Swaps cases, lower case becomes upper case and vice versa

# %%
"water".swapcase()
# Out:
# 'WATER'

# %%
"WATER".swapcase()
# Out:
# 'water'

# %%
"wATer".swapcase()
# Out:
# 'WatER'

# %% [markdown]
# ### 41. title()	Converts the first character of each word to upper case

# %%
"life of pie".title()
# Out:
# 'Life Of Pie'

# %%
"3tiger".title()
# Out:
# '3Tiger'

# %%
"5g5g5g5g everywhere!".title()
# Out:
# '5G5G5G5G Everywhere!'

# %% [markdown]
# ### 42. rstrip()	Returns a right trim version of the string

# %%
"          course    ".rstrip()
# Out:
# '          course'

# %%
"--csecoursecsecse-".rstrip("cse-")
# Out:
# '--csecour'

# %% [markdown]
# ### 43. translate()	Returns a translated string

# %%
txt = "Strong"
assign_value=str.maketrans("o","i")
print(txt.translate(assign_value))
# Out:
# String

# %%
secert_message = "t12l5t9"
code_alpha=str.maketrans("1234567890", "abcdefghij") #it matches character by character
print(secert_message.translate(code_alpha))
# Out:
# tableti

# %% [markdown]
# ### 44. upper()	Converts a string into upper case

# %%
"india".upper()
# Out:
# 'INDIA'

# %%
"tHe rIVer fLows".upper()
# Out:
# 'THE RIVER FLOWS'

# %% [markdown]
# ### 45. zfill()	Fills the string with a specified number of 0 values at the beginning

# %%
"Zenbook".zfill(20)
# Out:
# '0000000000000Zenbook'

# %%
"8".zfill(5)
# Out:
# '00008'

# %% [markdown]
# # Task 1 completed ;)
