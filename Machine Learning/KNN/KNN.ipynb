# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,KFold
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %%
wine_data = pd.DataFrame(data=load_wine().data,columns=load_wine().feature_names)

# %%
wine_data["Target"] = load_wine().target

# %%
wine_data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
wine_data["Target"].value_counts()
# Out:
# Target
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %%
wine_data.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# Target                          0
# dtype: int64

# %%
wine_data.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# Target                            int64
# dtype: object

# %%
X=wine_data.drop("Target",axis=1)
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
y = wine_data["Target"]

# %%
std_scalar = StandardScaler()
scalar_X=std_scalar.fit_transform(X)
pd.DataFrame(scalar_X)
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997  1.034819
# 1    0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648  0.733629
# 2    0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997  1.215533
# 3    1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446  1.466525
# 4    0.295700  0.227694  1.840403  0.451946  1.281985  0.808997  0.663351
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614 -1.424900
# 174  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334 -1.284344
# 175  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824 -1.344582
# 176  0.209232  0.227694  0.012732  0.151661  1.422412 -1.033684 -1.354622
# 177  1.395086  1.583165  1.365208  1.502943 -0.262708 -0.392751 -1.274305
#
#            7         8         9         10        11        12
# ...

# %%
X_train, X_test, y_train, y_test=train_test_split(scalar_X,y,test_size=0.20,random_state=42,shuffle=True,stratify=y)

# %% [markdown]
# ## KNN Algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
y_pred_train = knn.predict(X_train)
print("Accuracy Score:",accuracy_score(y_train,y_pred_train))
# Out:
# Accuracy Score: 0.9647887323943662

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred_train = knn.predict(X_train)
print("Accuracy Score:",accuracy_score(y_train,y_pred_train))
# Out:
# Accuracy Score: 0.9788732394366197

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
y_pred_train = knn.predict(X_train)
print("Accuracy Score:",accuracy_score(y_train,y_pred_train))
# Out:
# Accuracy Score: 0.971830985915493

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train,y_train)
y_pred_train = knn.predict(X_train)
print("Accuracy Score:",accuracy_score(y_train,y_pred_train))
# Out:
# Accuracy Score: 0.9647887323943662

# %% [markdown]
# ## How to choose the optimal number of neighbours

# %%
best_accuracy_score = 0 
best_n=0
for n in range(3,52):
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train,y_train)
    y_pred_train = knn.predict(X_train)
   
    current_ac_score = accuracy_score(y_train,y_pred_train)

    if(current_ac_score>best_accuracy_score):
        best_accuracy_score=current_ac_score
        best_n=n

print("N:",best_n,"\nAccuracy Score:",best_accuracy_score)
# Out:
# N: 5
# Accuracy Score: 0.9788732394366197

# %%
best_score=0
bestof_n = 0

fold = KFold(n_splits=10,shuffle=True,random_state=42)

for n in range(3,52,2):
    
    knn=KNeighborsClassifier(n_neighbors=n)
    
    cv=cross_val_score(estimator=knn,X=scalar_X,y=y,cv=fold)
    
    current_score = np.mean(cv)

    if(current_score>best_score):
        best_score=current_score
        bestof_n=n

print("Score:",best_score,"\nBest_n:",bestof_n)
# Out:
# Score: 0.9777777777777779
# Best_n: 11

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_neighbors': list(range(3,52,2))}

knn = KNeighborsClassifier()

grid = GridSearchCV(knn, param_grid, cv=fold)
grid.fit(scalar_X, y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.9777777777777779
# {'n_neighbors': 11}

# %% [markdown]
# Cross‑Validation is used to evaluate a model’s performance.
# GridSearchCV is used to tune hyperparameters, and it uses CV internally.
# So CV = evaluation, GridSearchCV = tuning + evaluation.
